# %%
#!/usr/bin/env python3

"""
Created on Mon Oct  29 14:54:00 2021

@author: robertamarinei

This is a version which analyses all the 4 channel of the LeCroy telescopes.

"""


    

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplotlib
from datetime import datetime
from scipy.stats import norm




#f  = open('caen_test.txt')
#f  = open('test_data.txt')
#path = '../Data_ExcelAcquisition/1400PMT_017_noDrift/result.txt'
#path = '../Data_ExcelAcquisition/1400PMT_017/result.txt'
#path =  "../Data_ExcelAcquisition/ScopeSet_1/1400TPC_017/"#200 events
#path =  "../Data_ExcelAcquisition/ScopeSet_1/1400TPC_017_noDrift/"#109 events
#path =  "../Data_ExcelAcquisition/ScopeSet_2/1400TPC_017/"#200
#path =  "../Data_ExcelAcquisition/ScopeSet_2/1400TPC_017_noDrift/"#198
#path =  "../Data_ExcelAcquisition/ScopeSet_2/noDrift_GEMon/"#200
#path = "../Data_ExcelAcquisition/ThGEM2750/noDrift_1200ThGEMon_ii/"
#tot_evt = 200 #200
#path = "../Data_ExcelAcquisition/ThGEM2750/CosmicTelescope/1250_1150_1100/"
#tot_evt = 10

#path = "../Data_ExcelAcquisition/ThGEM2750/CosmicTelescope/1250_1150_1100_lpf_iii/"
#tot_evt = 4

#path = "../Data_ExcelAcquisition/ThGEM2750/CosmicTelescope/1250_1150_1100_lpf_iv/"
#tot_evt = 89

path = "../Data_ExcelAcquisition/ThGEM2750/CosmicTelescope/DriftField_vary/"
tot_evt = 74
trig_offset = 0#seconds. i.e. trigger offset is centred on the middle of the screen
volt_lim = -0.009



path = "../Data_ExcelAcquisition/ThGEM2750/CosmicTelescope/C7500_M1600_Up1200_Dn100/"
tot_evt = 10
trig_offset = 0#seconds. i.e. trigger offset is centred on the middle of the screen
volt_lim = -0.009


#path =  "../Data_ExcelAcquisition/ThGEM2750/1200ThGEM/"
#tot_evt = 200 #200
#trig_offset = 0#seconds. i.e. trigger offset is centred on the middle of the screen
#volt_lim = -0.009


# path =  "../Data_ExcelAcquisition/ThGEM2750/Setup3/1300ThGEM_noDrift/"
# tot_evt = 200 #200
# trig_offset = -3e-5#seconds. i.e. trigger offset is centred on the middle of the screen
# volt_lim = -0.009




#path =  "../Data_ExcelAcquisition/ThGEM2750/Setup2/1200ThGEM/"
#tot_evt = 182 #200
#trig_offset = -15e-6#seconds

f = open(path+"result.txt",'r')
#f = open('CAENGECO2020_update.txt')

# %%
ampl_TPC = []
time_TPC = []

all_ampl_TPC = []

ampl_ScintUp = []
time_ScintUp = []

ampl_ScintDn = []
time_ScintDn = []

ampl_Coinc = []
time_Coinc = []

dum_wf_sum= 0
wf_sum_Scint = []
wf_sum_TPC = []
time_st = []
bin_info= []
Int_aft = []
Int_bef = []
sat_evt = []
sat_evt2 = []

evt_no = []
evt_no_good = []
for i in range(tot_evt):
    evt_no.append(i)

for i in range(tot_evt):
    ampl_TPC.append([])    
    time_TPC.append([])
    
    ampl_ScintUp.append([])
    time_ScintUp.append([])

    ampl_ScintDn.append([])
    time_ScintDn.append([])

    ampl_Coinc.append([])
    time_Coinc.append([])
    
    Int_bef.append(0)
    Int_aft.append(0)

#read data and store them in a list of list
dis = f.readlines()
f.close()
for i in dis:
        evt_,ch_,time_,ampl_ = i.split(',')
        if (ch_ == "C1"):
                ampl_ScintUp[int(evt_)].append(float(ampl_))
                time_ScintUp[int(evt_)].append(float(time_))
        elif (ch_ == "C2"): 
                ampl_ScintDn[int(evt_)].append(float(ampl_))   
                time_ScintDn[int(evt_)].append(float(time_))
        elif (ch_ == "C3"): 
                ampl_Coinc[int(evt_)].append(float(ampl_))   
                time_Coinc[int(evt_)].append(float(time_))
        elif (ch_ == "C4"): 
                ampl_TPC[int(evt_)].append(float(ampl_))   
                time_TPC[int(evt_)].append(float(time_))                
        


for i in range(len(ampl_TPC[0])):
    wf_sum_Scint.append(0)
    wf_sum_TPC.append(0)


trigger_level = -0.017#volts
   

#    wf_sum_Scint.append(dum_wf_sum) 
#    wf_sum_TPC.append(dum_wf_sum_TPC)    
#    time_st.append(time_Scint[0][i])
            
fake_trigger = 0

#--------------------
#integrals before and after the trigger offset 
#--------------------
for i in  range(len(ampl_TPC)):
    for j in range(len(ampl_TPC[0])): 
        if (time_TPC[i][j]<trig_offset):
            Int_bef[i]+=abs(ampl_TPC[i][j])
        elif (time_TPC[i][j]>trig_offset):
            Int_aft[i]+=abs(ampl_TPC[i][j])

            
#--------------------
#determine which events are saturated and store them in sat_evt list
#--------------------
for i in range(len(evt_no)):
    if (Int_aft[i] > 240): 
        print ("method 1", evt_no[i], Int_aft[i])
        sat_evt.append(evt_no[i])
evt_no_good = evt_no    

#--------------------
#Do the waveform sum 
#--------------------

for i in  range(len(ampl_TPC)):
    #if i in sat_evt:  continue
    for j in range(len(ampl_TPC[0])):    
            all_ampl_TPC.append(ampl_TPC[i][j])
            wf_sum_Scint[j] += ampl_ScintUp[i][j] 
            wf_sum_TPC[j] += ampl_TPC[i][j]

time_st = time_ScintUp[0]
# Out:
# method 1 0 480.0562999999145
# method 1 1 473.6188000000942
# method 1 2 476.5312999999509
# method 1 3 473.6513000000194
# method 1 4 473.7144250000744
# method 1 5 478.6112999999552
# method 1 6 476.25067500005355
# method 1 7 479.25254999992757
# method 1 8 476.68317500005605
# method 1 9 478.7087999999197
# [476.74312499997916, 474.3331250000404, 478.9037500000115, 475.38937500004766, 473.85375000005286, 477.58437500000656, 480.29562499992716, 480.2912499999181, 477.45124999999604, 480.0874999998767]

# %%
int_hist, int_hist_s = plt.subplots(1, 3, figsize=(16, 4), sharey=False)
int_hist_s[0].hist(Int_bef,range= (0, 800))
int_hist_s[0].set_title("Integral before the trigger for all events")
int_hist_s[0].set_xlabel("Amplitude [V]")
int_hist_s[1].hist(Int_aft, range= (0, 800))
int_hist_s[1].set_title("Integral after the trigger for all events")
int_hist_s[1].set_xlabel("Amplitude [V]")
int_hist_s[2].plot(evt_no,Int_aft)
int_hist_s[2].set_title("Evt Number vs wf integral after trigger")
int_hist_s[2].set_xlabel("Event Number ")
int_hist_s[2].set_ylabel("Waveform sum ")

int_hist.savefig(path+"integrals.pdf")

# %%
#plt.bar(time_TPC[0], wf_sum)
#plt.bar(x,y)
fig, axs = plt.subplots(1, 2, figsize=(10, 4), sharey=False)
# Set common labels
print ("size of time_st " , len(time_st), "  size o wf_sum_TPC ", len(wf_sum_Scint) )

axs[0].set_xlabel('Acquisiton Time [s]')
axs[0].set_ylabel('Amplitude Added [V]')
axs[1].set_xlabel('Acquistion Time [s]')
axs[0].plot(time_st, wf_sum_Scint)
axs[1].plot(time_st,wf_sum_TPC)
fig.savefig(path+"wf_added.pdf")
# Out:
# size of time_st  50000   size o wf_sum_TPC  50000

# %%
fig2, axs2 = plt.subplots(1, 2, figsize=(10, 4), sharey=False)
axs2[0].set_xlabel('Acquisiton Time [s]')
axs2[0].set_ylabel('Amplitude  [V]')
axs2[1].set_xlabel('Acquistion Time [s]')

range_min_1 = next(x for x, val in enumerate(time_ScintUp[1]) if val > -0.1e-5)
range_max_1 = next(x for x, val in enumerate(time_ScintUp[1]) if val > 0.1e-5)


x = time_ScintUp[1][range_min_1:range_max_1]
evt_pl =8

y = ampl_Coinc[evt_pl][range_min_1:range_max_1]
z = ampl_TPC[evt_pl][range_min_1:range_max_1]


y2 = ampl_Coinc[evt_pl+1][range_min_1:range_max_1]
z2 = ampl_TPC[evt_pl+1][range_min_1:range_max_1]


axs2[0].set_title(evt_pl)
axs2[1].set_title(evt_pl +1)

#axs2[0].plot(x,y)
#axs2[0].plot(x,z)


#axs2[0].plot(time_ScintUp[1],ampl_ScintUp[evt_pl])
axs2[0].plot(time_TPC[1],ampl_TPC[evt_pl])


#axs2[1].plot(x,y2)
#axs2[1].plot(x,z2)

#axs2[1].plot(time_ScintUp[1],ampl_ScintUp[evt_pl])
axs2[1].plot(time_TPC[1],ampl_TPC[evt_pl])


fig2.savefig(path+"single_events.pdf")

# %%
# import pandas
import pandas as pd

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
evt_pl = sat_evt[5]
ax.set_title(evt_pl)
# make a plot
ax.plot(time_ScintUp[4],ampl_ScintUp[evt_pl])
# set x-axis label
ax.set_xlabel("Acquisition Window [s]",fontsize=14)
# set y-axis label

ax.set_ylabel("Scintillator Amplitude",color="blue",fontsize=14)
#Next we use twinx() function to create the second axis object “ax2”. Now we use the second axis object “ax2” to make plot of the second y-axis variable and update their labels.
# twin object for two different y-axis on the sample plot


ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(time_TPC[4],ampl_TPC[evt_pl], color = "red")
ax2.set_ylabel("TPC Amplitude",color="red",fontsize=14)
plt.show()
# save the plot as a file
fig.savefig(path+'single_event_diff_axis.pdf',
            format='pdf', bbox_inches='tight')
